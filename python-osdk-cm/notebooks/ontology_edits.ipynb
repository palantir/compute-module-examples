# %%
#  Copyright 2025 Palantir Technologies, Inc.
#
#  Licensed under the Apache License, Version 2.0 (the "License");
#  you may not use this file except in compliance with the License.
#  You may obtain a copy of the License at
#
#      http://www.apache.org/licenses/LICENSE-2.0
#
#  Unless required by applicable law or agreed to in writing, software
#  distributed under the License is distributed on an "AS IS" BASIS,
#  WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
#  See the License for the specific language governing permissions and
#  limitations under the License.

import os
import json
from typing import Any
from pokemon_app_sdk import FoundryClient
from pokemon_app_sdk.core.api import UserTokenAuth
from foundry_sdk_runtime.auth import ConfidentialClientAuth
from pokemon_app_sdk.ontology.objects import SkruyswykPokemon
from foundry_sdk_runtime.ontology_edit import (
    AddObject,
    DeleteObject,
    ModifyObject,
    ObjectLocator,
)

# %%
HOSTNAME = "<INSERT STACK URL>"
auth = ConfidentialClientAuth(
    client_id=os.environ['CLIENT_ID'],
    client_secret=os.environ['CLIENT_SECRET'],
    hostname=HOSTNAME,
    should_refresh=True,
)
auth.sign_in_as_service_user()

client = FoundryClient(auth=auth, hostname=HOSTNAME)

# %%
ontology_edits = client.ontology.edits()

# %%
editable_object = ontology_edits.objects.SkruyswykPokemon.edit("Ivysaur")

# %%
bulbasaur_locator = ObjectLocator(object_api_name="SkruyswykPokemon", primary_key="Bulbasaur")
ivysaur_locator = ObjectLocator(object_api_name="SkruyswykPokemon", primary_key="Ivysaur")

# %%
ontology_edits.add_link("evolvesFrom", source=ivysaur_locator, target=bulbasaur_locator)

# %%
ontology_edits.get_edits()

# %%
setattr(editable_object, "sp_def", getattr(editable_object, "sp_def") + 1)

# %%
editable_object

# %%
e1 = ontology_edits.get_edits()[0]

# %%
fully_qualified_type_name(e1)

# %%
def fully_qualified_type_name(edit: Any) -> str:
    return f"{type(edit).__module__}.{type(edit).__name__}"

# %%
property_ids = {
    "spDef": "sp_def"
}

# %%
e1

# %%
e1.fields

# %%
help(ontology_edits.objects.SkruyswykPokemon.create)

# %%
added_object = ontology_edits.objects.SkruyswykPokemon.create(
    name="Marshmallow",
    id=999,
    type1="Normal",
    type2="Delicious",
    generation="10",
    sp_def=60,
    sp_atk=70,
    speed=80,
    attack=90,
    defense=100,
    hp=100,
    total=500,
    legendary=True,
)

# %%
e1 = ontology_edits.get_edits()[0]

# %%
e1

# %%
deleted_object = ontology_edits.objects.SkruyswykPokemon.delete("Ivysaur")

# %%
e1 = ontology_edits.get_edits()[0]
e1

# %%
help(ontology_edits.add_link)

# %%
editable_object = ontology_edits.objects.SkruyswykPokemon.edit("Ivysaur")

# %%
editable_object.precursor = "Bulbasaur"

# %%
ontology_edits.get_edits()

# %%
ontology_edits.add_link(
    "skruyswyk-pokemon-skruyswyk-pokemon",
    source="Ivysaur",
    target="Bulbasaur"
)

# %%
ontology_edits.get_edits()
